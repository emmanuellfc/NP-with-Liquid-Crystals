# %% [markdown]
# # Thermodynamical Analysis

# %% [markdown]
# ## Mesogens with NP | Pressure Ramps

# %% [markdown]
# ### System P = 1.8, Expected value of $T_c$ :

# %% [markdown]
# This notebook is used for ramps and system equilibriums, that's why is convenient to define a variable in which we store the name of the file in which all the information will be saved.
# The structure of the file name is this: T + temperature value + P + pressure value + "part of the simulation".
# Part of the "simulation" could be ramp and equilibrium.

# %%
# !pwd
# Out:
# /home/emmanuel/Simulations/NP-with-Liquid-Crystals/Cluster/P_18

# %% [markdown]
# ## Pressure Ramp

# %%
#-----Import packages.

import numpy
from matplotlib import pyplot

# %%
#-----Define variables.

t_max = 7.8;
p_max = 1.8;
simulation_part = "equilibrium";

# %%
#-----Declare ta file name.

file_name = "T_" + str(t_max) + "_P_" + str(p_max) + "_" + simulation_part + ".log"

# %%
#-----Declare the file on wich read all of the thermodynamical properties.

data = numpy.genfromtxt(fname = file_name, skip_header=True);

# %%
#-----Compute presure, temperature and its standard deviations.

mean_p = numpy.mean(data[:,10]);
std_p = numpy.std(data[:,10]);
mean_temp = numpy.mean(data[-50000:-1,9])
std_temp = numpy.std(data[-50000:-1,9])
mean_volume = numpy.mean(data[:,11])

# %% [markdown]
# ## Values of Pressure and Temperature

# %%
print("P =", mean_p, "+-",std_p)
# Out:
# P = nan +- nan

# %%
print("T =", mean_temp, "+-", std_temp)
# Out:
# T = nan +- nan

# %%
print("Mean volume = ", mean_volume)
# Out:
# Mean volume =  nan

# %% [markdown]
# ## Graphics

# %%
pyplot.figure(figsize = (7,4), dpi = 140);
pyplot.plot(data[:,0], data[:,10], "g");
pyplot.xlabel('Time step');
pyplot.ylabel('Pressure');
pyplot.suptitle("Equilibrium," + " T = " + str(t_max) + ", P = " + str(p_max));
pyplot.grid(True, color = 'k', linestyle = '--', linewidth = 0.1);
#pyplot.savefig(fname = "Pressure_T_" + str(t_max) + "_P_" + str(p_max) + ".png", format = "png");

# %%
pyplot.figure(figsize = (7,4), dpi = 140);
pyplot.plot(data[:,0], data[:,9], "r");
pyplot.xlabel('Time step');
pyplot.ylabel('Temperature');
pyplot.suptitle("Equilibrium," + " T = " + str(t_max) + ", P = " + str(p_max));
pyplot.grid(True, color = 'k', linestyle = '--', linewidth = 0.1);
#pyplot.savefig(fname = "Temperature_T_" + str(t_max) + "_P_" + str(p_max) + ".png", format = "png");

# %%
pyplot.figure(figsize = (7,4), dpi = 140);
pyplot.plot(data[:,0], data[:,5]);
pyplot.xlabel('Time step');
pyplot.ylabel('Potential energy');
pyplot.suptitle(simulation_part + " - "+ "T = " + str(t_max) + ' & ' + "P = " + str(p_max));
pyplot.grid(True, color = 'k', linestyle = '--', linewidth = 0.1);
#pyplot.savefig(fname = "Potential_Energy_T_" + str(t_max) + "_P_" + str(p_max) + ".png", format = "png");

# %%
pyplot.figure(figsize = (7,4), dpi = 140);
pyplot.plot(data[:,0], data[:,6]);
pyplot.xlabel('Time step');
pyplot.ylabel('Kinetic energy');
pyplot.suptitle(simulation_part + " - "+ "T = " + str(t_max) + ' & ' + "P = " + str(p_max));
pyplot.grid(True, color = 'k', linestyle = '--', linewidth = 0.1);
#pyplot.savefig(fname = "Kinetic_Energy_T_" + str(t_max) + "_P_" + str(p_max)+ ".png", format = "png");

# %%
pyplot.figure(figsize = (7,4), dpi = 140);
pyplot.plot(data[:,0], data[:,7]);
pyplot.xlabel('Time step');
pyplot.ylabel('Translational kinetic energy');
pyplot.suptitle(simulation_part + " - "+ "T = " + str(t_max) + ' & ' + "P = " + str(p_max));
pyplot.grid(True, color = 'k', linestyle = '--', linewidth = 0.1);
#pyplot.savefig(fname = "TRanslational_Kinetic_Energy_T_" + str(t_max) + "_P_" + str(p_max) + ".png", format = "png");

# %%
pyplot.figure(figsize = (7,4), dpi = 140);
pyplot.plot(data[:,0], data[:,8]);
pyplot.xlabel('Time step');
pyplot.ylabel('Rotational kinetic energy');
pyplot.suptitle(simulation_part + " - "+ "T = " + str(t_max) + ' & ' + "P = " + str(p_max));
pyplot.grid(True, color = 'k', linestyle = '--', linewidth = 0.1);
#pyplot.savefig(fname = "Rotational__Kinetic_Energy_T_" + str(t_max) + "_P_" + str(p_max) + ".png", format = "png");
