# %% [markdown]
# # Thermodynamical Analysis

# %% [markdown]
# ## Temperature Ramp

# %%
#-----Import packages.

import numpy
from matplotlib import pyplot

# %%
#-----Define variables

t_fin = 9.0; 
press = 2.3;

# %%
#-----Declare the file from wich we'll extract the configuration of the system.

ramp_file = "T_" + str(t_fin) + "_P_" + str(press) + "_equilibrium.log"

# %%
#-----Declare the file on wich compute all of the thermodynamical properties.

data = numpy.genfromtxt(fname = ramp_file, skip_header=True);

# %%
#-----Compute presure, temperature and its standard deviations.

mean_p = numpy.mean(data[:,10]);
std_p = numpy.std(data[:,10]);
mean_temp = numpy.mean(data[:,9])
std_temp = numpy.std(data[:,9])

# %% [markdown]
# ## Values of Pressure and Temperature

# %%
print("P =", mean_p, "+-",std_p)
# Out:
# P = nan +- nan

# %%
print("T =", mean_temp, "+-", std_temp)
# Out:
# T = nan +- nan

# %% [markdown]
# ## Graphics

# %%
pyplot.figure(figsize=(4,2.2), dpi=140);
pyplot.plot(data[:,0], data[:,10]);
pyplot.xlabel('time step');
pyplot.ylabel('Pressure');
pyplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
pyplot.figure(figsize=(4,2.2), dpi=140);
pyplot.plot(data[:,0], data[:,9]);
pyplot.xlabel('Time step');
pyplot.ylabel('Temperature');
pyplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
pyplot.figure(figsize=(4,2.2), dpi=140);
pyplot.plot(data[:,0], data[:,5]);
pyplot.xlabel('time step');
pyplot.ylabel('Potential Energy');
#pyplot.axis([0,2e5,-4.5e4,-3e4]);
pyplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
pyplot.figure(figsize=(4,2.2), dpi=140);
pyplot.plot(data[:,0], data[:,6]);
pyplot.xlabel('time step');
pyplot.ylabel('Kinetic Energy');
pyplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
pyplot.figure(figsize=(4,2.2), dpi=140);
pyplot.plot(data[:,0], data[:,7]);
pyplot.xlabel('time step');
pyplot.ylabel('Translational Kinetic Energy');
pyplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
pyplot.figure(figsize=(4,2.2), dpi=140);
pyplot.plot(data[:,0], data[:,8]);
pyplot.xlabel('time step');
pyplot.ylabel('Rotational Kinetic Energy');
pyplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')
